# %% [markdown]
# ### This is use to test the code and debug

# %%
from jamaibase import JamAI, types as t

client = JamAI(
    project_id="proj_8be41840951664166d7f727c",
    token="jamai_pat_e71780d2ad8e1883dd1a97616bcd314ddfb42061af51478a"
)

tables = client.table.list_tables(table_type=t.TableType.ACTION)

for tb in tables.items:
    print("TABLE ID:", tb.id)
# Out:
# TABLE ID: 3. Final Conclusion
# TABLE ID: 2. User Clarification
# TABLE ID: 1. Detect the Problem
